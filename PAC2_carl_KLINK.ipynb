# %% [markdown]
# ### Exercise 1

# %% [markdown]
# (a) A global variable can be modified inside a function. **Answer:** True
#
# A `global` variable can be modified inside a function by using the global keyword. This keyword tells the function to refer to the `global` variable rather than creating a local one.
#
# Example :

# %%
x = 10

def modify_global():
    global x
    x = 20

modify_global()
x
# Out:
# 20

# %% [markdown]
# (b) We must always close the file with the sentence `close()` even if it has been opened with the sentence `with`.
# **Answer:** False. When using the `with` statement to open a file, there's no need to explicitly close the file using `close()`. The `with` statement automatically handles closing the file when it goes out of scope, ensuring proper resource management.

# %% [markdown]
# (c) The function filter takes as parameters a function and an iterable, and returns an iterator that applies the given function to each of the iterable's elements.
# **Answer:** True
#
# The filter() function in Python takes two parameters: a function and an iterable. It returns an iterator that yields the elements from the iterable for which the function returns true. The function provided serves as a filter, determining which elements are included in the resulting iterator.

# %%
def is_even(n):
    return n % 2 == 0

numbers = [1, 2, 3, 4, 5]
even_numbers = filter(is_even, numbers)
print(list(even_numbers))
# Out:
# [2, 4]

# %% [markdown]
# (d) Anonymous functions are a type of functions that do not have a name and can be defined in more than one expression.
# **Answer:** False
#
# Anonymous functions, often referred to as lambda functions in Python, do not have a name and are defined using the lambda keyword. They are limited to a single expression and cannot contain multiple statements or expressions.

# %%
square = lambda x: x * x
print(square(5))
# Out:
# 25

# %% [markdown]
# ### Exercise 2

# %%
import os
import pandas as pd

def create_draft_db(input_path, output_path, years_back=5, players_per_year=5):
    """
    Create a draft database structure based on NHL draft information.
    
    Args:
    - input_path (str): Path to the NHL draft CSV file.
    - output_path (str): Path to the output directory where the draft database will be created.
    - years_back (int, optional): Number of previous years to create folders for. Default is 5.
    - players_per_year (int, optional): Number of top players per year to save. Default is 5.
    
    Returns:
    - None
    """
    # Load draft data
    draft_data = pd.read_csv(input_path)
    
    # Get unique years
    unique_years = draft_data['year'].unique()
    
    # Determine the range of years to create folders for
    years_range = range(max(unique_years), max(unique_years) - years_back, -1)
    
    # Create draft database structure
    for year in years_range:
        year_folder = os.path.join(output_path, str(year))
        if not os.path.exists(year_folder):
            os.makedirs(year_folder)
        
        # Filter draft data for the current year
        year_data = draft_data[draft_data['year'] == year]
        
        # Get top players per nationality
        top_players = year_data.groupby('nationality').head(players_per_year)
        
        for nationality, player_info in top_players.groupby('nationality'):
            nationality_folder = os.path.join(year_folder, nationality)
            if not os.path.exists(nationality_folder):
                os.makedirs(nationality_folder)
                
            for idx, player in player_info.iterrows():
                player_folder = os.path.join(nationality_folder, player['player'])
                if not os.path.exists(player_folder):
                    os.makedirs(player_folder)
                
                # Create info.txt file for each player
                info_file = os.path.join(player_folder, 'info.txt')
                with open(info_file, 'w') as f:
                    f.write(f"Team: {player['team']}; Amateur_team: {player['amateur_team']}; "
                            f"Age: {player['age']}; Position: {player['position']}")
    
    print("Draft database structure created successfully!")

# Example usage:
create_draft_db("D:/Donwloads/nhldraft.csv", "D:/Donwloads/PAC2", years_back=20, players_per_year=20)
# Out:
# Draft database structure created successfully!

# %% [markdown]
# ## Exercise 3

# %%
import csv

def read_csv_to_list_of_dicts(csv_file):
    """
    Read a CSV file and save the data in a list of dictionaries.
    
    Args:
    - csv_file (str): Path to the CSV file.
    
    Returns:
    - list: List of dictionaries containing the data from the CSV file.
    """
    data = []
    with open(csv_file, 'r', newline='') as file:
        reader = csv.DictReader(file)
        for row in reader:
            data.append(row)
    return data

def players_selected_by_team(players_list, team_name):
    """
    Filter players' information based on the professional team that selected them.
    
    Args:
    - players_list (list): List of dictionaries containing players' information.
    - team_name (str): Name of the professional team.
    
    Returns:
    - list: List of dictionaries containing players' information selected by the specified team.
    """
    return list(filter(lambda player: player['team'] == team_name, players_list))

def total_players_per_year(players_list):
    """
    Calculate the total number of players that have been drafted per year.
    
    Args:
    - players_list (list): List of dictionaries containing players' information.
    
    Returns:
    - dict: Dictionary where keys are years and values are the total number of players drafted in that year.
    """
    players_per_year = {}
    for player in players_list:
        year = player['year']
        players_per_year[year] = players_per_year.get(year, 0) + 1
    return players_per_year

# Example usage:
draft_data = read_csv_to_list_of_dicts("D:/Donwloads/nhldraft.csv")
selected_players = players_selected_by_team(draft_data, "New York Rangers")
print("Players selected by New York Rangers:")
for player in selected_players:
    print(player)
# Out:
# Players selected by New York Rangers:
# {'id': '63', 'year': '2022', 'overall_pick': '63', 'team': 'New York Rangers', 'player': 'Adam Sykora', 'nationality': 'SK', 'position': 'LW', 'age': '18', 'to_year': '', 'amateur_team': 'HK Nitra (Slovakia)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '97', 'year': '2022', 'overall_pick': '97', 'team': 'New York Rangers', 'player': 'Bryce Mcconnell-Barker', 'nationality': 'CA', 'position': 'C', 'age': '18', 'to_year': '', 'amateur_team': 'Soo Greyhounds (OHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '111', 'year': '2022', 'overall_pick': '111', 'team': 'New York Rangers', 'player': 'Noah Laba', 'nationality': 'US', 'position': 'C', 'age': '19', 'to_year': '', 'amateur_team': 'Lincoln Stars (USHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '159', 'year': '2022', 'overall_pick': '159', 'team': 'New York Rangers', 'player': 'Vittorio Mancini', 'nationality': 'US', 'position': 'D', 'age': '20', 'to_year': '', 'amateur_team': 'Nebraska-Omaha (NCHC)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '161', 'year': '2022', 'overall_pick': '161', 'team': 'New York Rangers', 'player': 'Maxim Barbashev', 'nationality': 'RU', 'position': 'LW', 'age': '18', 'to_year': '', 'amateur_team': 'Moncton Wildcats (QMJHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '191', 'year': '2022', 'overall_pick': '191', 'team': 'New York Rangers', 'player': 'Zakary Karpa', 'nationality': 'US', 'position': 'C', 'age': '20', 'to_year': '', 'amateur_team': 'Harvard (ECAC)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '240', 'year': '2021', 'overall_pick': '16', 'team': 'New York Rangers', 'player': 'Brennan Othmann', 'nationality': 'CA', 'position': 'LW', 'age': '18', 'to_year': '', 'amateur_team': 'Flint Firebirds (OHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '289', 'year': '2021', 'overall_pick': '65', 'team': 'New York Rangers', 'player': 'Jayden Grubbe', 'nationality': 'CA', 'position': 'C', 'age': '18', 'to_year': '', 'amateur_team': 'Red Deer Rebels (WHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '299', 'year': '2021', 'overall_pick': '75', 'team': 'New York Rangers', 'player': 'Ryder Korczak', 'nationality': 'CA', 'position': 'C', 'age': '18', 'to_year': '', 'amateur_team': 'Moose Jaw Warriors (WHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '328', 'year': '2021', 'overall_pick': '104', 'team': 'New York Rangers', 'player': 'Brody Lamb', 'nationality': 'US', 'position': 'RW', 'age': '18', 'to_year': '', 'amateur_team': 'Dodge County HS (High-MN)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '330', 'year': '2021', 'overall_pick': '106', 'team': 'New York Rangers', 'player': 'Kalle Vaisanen', 'nationality': 'FI', 'position': 'LW', 'age': '18', 'to_year': '', 'amateur_team': 'TPS Jr. (Finland Jr.)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '336', 'year': '2021', 'overall_pick': '112', 'team': 'New York Rangers', 'player': 'Talyn Boyko', 'nationality': 'CA', 'position': 'G', 'age': '18', 'to_year': '', 'amateur_team': 'Tri-City Americans (WHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '368', 'year': '2021', 'overall_pick': '144', 'team': 'New York Rangers', 'player': 'Jaroslav Chmelar', 'nationality': 'CZ', 'position': 'RW', 'age': '18', 'to_year': '', 'amateur_team': 'Jokerit Jr. (Finland Jr.)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '432', 'year': '2021', 'overall_pick': '208', 'team': 'New York Rangers', 'player': 'Hank Kempf', 'nationality': 'US', 'position': 'D', 'age': '19', 'to_year': '', 'amateur_team': 'Muskegon Lumberjacks (USHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '449', 'year': '2020', 'overall_pick': '1', 'team': 'New York Rangers', 'player': 'Alexis Lafreniere', 'nationality': 'CA', 'position': 'LW', 'age': '18', 'to_year': '2022', 'amateur_team': 'Rimouski Oceanic (QMJHL)', 'games_played': '135', 'goals': '31', 'assists': '21', 'points': '52', 'plus_minus': '-5', 'penalties_minutes': '45', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '5'}
# {'id': '467', 'year': '2020', 'overall_pick': '19', 'team': 'New York Rangers', 'player': 'Braden Schneider', 'nationality': 'CA', 'position': 'D', 'age': '18', 'to_year': '2022', 'amateur_team': 'Brandon Wheat Kings (WHL)', 'games_played': '43', 'goals': '2', 'assists': '9', 'points': '11', 'plus_minus': '5', 'penalties_minutes': '9', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '2.4'}
# {'id': '507', 'year': '2020', 'overall_pick': '60', 'team': 'New York Rangers', 'player': 'William Cuylle', 'nationality': 'CA', 'position': 'LW', 'age': '18', 'to_year': '', 'amateur_team': 'Windsor Spitfires (OHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '539', 'year': '2020', 'overall_pick': '92', 'team': 'New York Rangers', 'player': 'Oliver Tarnstrom', 'nationality': 'SE', 'position': 'C', 'age': '18', 'to_year': '', 'amateur_team': 'AIK Jr. (Sweden Jr.)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '550', 'year': '2020', 'overall_pick': '103', 'team': 'New York Rangers', 'player': 'Dylan Garand', 'nationality': 'CA', 'position': 'G', 'age': '18', 'to_year': '', 'amateur_team': 'Kamloops Blazers (WHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '574', 'year': '2020', 'overall_pick': '127', 'team': 'New York Rangers', 'player': 'Evan Vierling', 'nationality': 'CA', 'position': 'C', 'age': '18', 'to_year': '', 'amateur_team': 'Barrie Colts (OHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '581', 'year': '2020', 'overall_pick': '134', 'team': 'New York Rangers', 'player': 'Brett Berard', 'nationality': 'US', 'position': 'LW', 'age': '18', 'to_year': '', 'amateur_team': 'USA U-18 Development Team (USDP/USHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '612', 'year': '2020', 'overall_pick': '165', 'team': 'New York Rangers', 'player': 'Matt Rempe', 'nationality': 'CA', 'position': 'C', 'age': '18', 'to_year': '', 'amateur_team': 'Seattle Thunderbirds (WHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '644', 'year': '2020', 'overall_pick': '197', 'team': 'New York Rangers', 'player': 'Hugo Ollas', 'nationality': 'SE', 'position': 'G', 'age': '18', 'to_year': '', 'amateur_team': 'Linkoping HC Jr. (Sweden Jr.)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '666', 'year': '2019', 'overall_pick': '2', 'team': 'New York Rangers', 'player': 'Kaapo Kakko', 'nationality': 'FI', 'position': 'RW', 'age': '18', 'to_year': '2022', 'amateur_team': 'TPS (Finland)', 'games_played': '157', 'goals': '26', 'assists': '32', 'points': '58', 'plus_minus': '-14', 'penalties_minutes': '34', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '3.8'}
# {'id': '713', 'year': '2019', 'overall_pick': '49', 'team': 'New York Rangers', 'player': 'Matthew Robertson', 'nationality': 'CA', 'position': 'D', 'age': '18', 'to_year': '', 'amateur_team': 'Edmonton Oil Kings (WHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '722', 'year': '2019', 'overall_pick': '58', 'team': 'New York Rangers', 'player': 'Karl Henriksson', 'nationality': 'SE', 'position': 'C', 'age': '18', 'to_year': '', 'amateur_team': 'Frolunda HC Jr. (Sweden Jr.)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '732', 'year': '2019', 'overall_pick': '68', 'team': 'New York Rangers', 'player': 'Zachary Jones', 'nationality': 'US', 'position': 'D', 'age': '18', 'to_year': '2022', 'amateur_team': 'Tri-City Storm (USHL)', 'games_played': '22', 'goals': '0', 'assists': '6', 'points': '6', 'plus_minus': '-9', 'penalties_minutes': '2', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '0.3'}
# {'id': '776', 'year': '2019', 'overall_pick': '112', 'team': 'New York Rangers', 'player': 'Hunter Skinner', 'nationality': 'US', 'position': 'D', 'age': '18', 'to_year': '', 'amateur_team': 'Lincoln Stars (USHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '794', 'year': '2019', 'overall_pick': '130', 'team': 'New York Rangers', 'player': 'Leevi Aaltonen', 'nationality': 'FI', 'position': 'RW', 'age': '18', 'to_year': '', 'amateur_team': 'KalPa Jr. (Finland Jr.)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '825', 'year': '2019', 'overall_pick': '161', 'team': 'New York Rangers', 'player': 'Adam Edstrom', 'nationality': 'SE', 'position': 'C', 'age': '18', 'to_year': '', 'amateur_team': 'Mora IK Jr. (Sweden Jr.)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '869', 'year': '2019', 'overall_pick': '205', 'team': 'New York Rangers', 'player': 'Eric Ciccolini', 'nationality': 'CA', 'position': 'RW', 'age': '18', 'to_year': '', 'amateur_team': 'Toronto (OJHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '890', 'year': '2018', 'overall_pick': '9', 'team': 'New York Rangers', 'player': 'Vitali Kravtsov', 'nationality': 'RU', 'position': 'RW', 'age': '18', 'to_year': '2021', 'amateur_team': 'Traktor Chelyabinsk (Russia)', 'games_played': '20', 'goals': '2', 'assists': '2', 'points': '4', 'plus_minus': '-6', 'penalties_minutes': '4', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '0'}
# {'id': '903', 'year': '2018', 'overall_pick': '22', 'team': 'New York Rangers', 'player': "K'Andre Miller", 'nationality': 'US', 'position': 'D', 'age': '18', 'to_year': '2022', 'amateur_team': 'USA U-18 Development Team (USDP/USHL)', 'games_played': '135', 'goals': '12', 'assists': '20', 'points': '32', 'plus_minus': '32', 'penalties_minutes': '44', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '9.6'}
# {'id': '909', 'year': '2018', 'overall_pick': '28', 'team': 'New York Rangers', 'player': 'Nils Lundkvist', 'nationality': 'SE', 'position': 'D', 'age': '18', 'to_year': '2022', 'amateur_team': 'Lulea HF (Sweden)', 'games_played': '25', 'goals': '1', 'assists': '3', 'points': '4', 'plus_minus': '4', 'penalties_minutes': '0', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '1.2'}
# {'id': '920', 'year': '2018', 'overall_pick': '39', 'team': 'New York Rangers', 'player': 'Olof Lindbom', 'nationality': 'SE', 'position': 'G', 'age': '18', 'to_year': '', 'amateur_team': 'Djurgardens IF Jr. (Sweden Jr.)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '951', 'year': '2018', 'overall_pick': '70', 'team': 'New York Rangers', 'player': 'Jacob Ragnarsson', 'nationality': 'US', 'position': 'D', 'age': '18', 'to_year': '', 'amateur_team': 'Almtuna IS (Sweden-2)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '969', 'year': '2018', 'overall_pick': '88', 'team': 'New York Rangers', 'player': 'Joey Keane', 'nationality': 'US', 'position': 'D', 'age': '19', 'to_year': '2022', 'amateur_team': 'Barrie Colts (OHL)', 'games_played': '2', 'goals': '0', 'assists': '0', 'points': '0', 'plus_minus': '-1', 'penalties_minutes': '2', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '0'}
# {'id': '982', 'year': '2018', 'overall_pick': '101', 'team': 'New York Rangers', 'player': 'Nico Gross', 'nationality': 'CH', 'position': 'D', 'age': '18', 'to_year': '', 'amateur_team': 'Oshawa Generals (OHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '1013', 'year': '2018', 'overall_pick': '132', 'team': 'New York Rangers', 'player': 'Lauri Pajuniemi', 'nationality': 'FI', 'position': 'RW', 'age': '19', 'to_year': '', 'amateur_team': 'TPS (Finland)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '1044', 'year': '2018', 'overall_pick': '163', 'team': 'New York Rangers', 'player': 'Simon Kjellberg', 'nationality': 'US', 'position': 'D', 'age': '18', 'to_year': '', 'amateur_team': 'Rogle BK Jr. (Sweden Jr.)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '1097', 'year': '2018', 'overall_pick': '216', 'team': 'New York Rangers', 'player': 'Riley Hughes', 'nationality': 'US', 'position': 'RW', 'age': '18', 'to_year': '', 'amateur_team': "St. Sebastian's School (High-MA)", 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '1105', 'year': '2017', 'overall_pick': '7', 'team': 'New York Rangers', 'player': 'Lias Andersson', 'nationality': 'SE', 'position': 'C', 'age': '18', 'to_year': '2022', 'amateur_team': 'HV71 (Sweden)', 'games_played': '109', 'goals': '7', 'assists': '10', 'points': '17', 'plus_minus': '-31', 'penalties_minutes': '57', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '-0.6'}
# {'id': '1119', 'year': '2017', 'overall_pick': '21', 'team': 'New York Rangers', 'player': 'Filip Chytil', 'nationality': 'CZ', 'position': 'C', 'age': '18', 'to_year': '2022', 'amateur_team': 'HC Ziln (Czech)', 'games_played': '253', 'goals': '42', 'assists': '51', 'points': '93', 'plus_minus': '-26', 'penalties_minutes': '46', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '6.7'}
# {'id': '1221', 'year': '2017', 'overall_pick': '123', 'team': 'New York Rangers', 'player': 'Brandon Crawley', 'nationality': 'US', 'position': 'D', 'age': '20', 'to_year': '', 'amateur_team': 'London Knights (OHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '1243', 'year': '2017', 'overall_pick': '145', 'team': 'New York Rangers', 'player': 'Calle Sjalin', 'nationality': 'SE', 'position': 'D', 'age': '18', 'to_year': '', 'amateur_team': 'Ostersunds IK (Sweden-3)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '1255', 'year': '2017', 'overall_pick': '157', 'team': 'New York Rangers', 'player': 'Dominik Lakatos', 'nationality': 'CZ', 'position': 'C', 'age': '20', 'to_year': '', 'amateur_team': 'Bili Tygri Liberec (Czech)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '1272', 'year': '2017', 'overall_pick': '174', 'team': 'New York Rangers', 'player': 'Morgan Barron', 'nationality': 'CA', 'position': 'C', 'age': '18', 'to_year': '2022', 'amateur_team': "St. Andrew's College (High-ON)", 'games_played': '32', 'goals': '3', 'assists': '3', 'points': '6', 'plus_minus': '-5', 'penalties_minutes': '10', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '0.2'}
# {'id': '1305', 'year': '2017', 'overall_pick': '207', 'team': 'New York Rangers', 'player': 'Patrik Virta', 'nationality': 'FI', 'position': 'C', 'age': '21', 'to_year': '', 'amateur_team': 'TPS (Finland)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '1396', 'year': '2016', 'overall_pick': '81', 'team': 'New York Rangers', 'player': 'Sean Day', 'nationality': 'BE', 'position': 'D', 'age': '18', 'to_year': '2022', 'amateur_team': 'Mississauga Steelheads (OHL)', 'games_played': '2', 'goals': '0', 'assists': '0', 'points': '0', 'plus_minus': '-2', 'penalties_minutes': '0', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '-0.1'}
# {'id': '1413', 'year': '2016', 'overall_pick': '98', 'team': 'New York Rangers', 'player': 'Tarmo Reunanen', 'nationality': 'FI', 'position': 'D', 'age': '18', 'to_year': '2021', 'amateur_team': 'TPS Jr. (Finland Jr.)', 'games_played': '4', 'goals': '0', 'assists': '1', 'points': '1', 'plus_minus': '1', 'penalties_minutes': '0', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '0.2'}
# {'id': '1456', 'year': '2016', 'overall_pick': '141', 'team': 'New York Rangers', 'player': 'Timothy Gettinger', 'nationality': 'US', 'position': 'LW', 'age': '18', 'to_year': '2022', 'amateur_team': 'Soo Greyhounds (OHL)', 'games_played': '16', 'goals': '0', 'assists': '1', 'points': '1', 'plus_minus': '-1', 'penalties_minutes': '0', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '-0.2'}
# {'id': '1486', 'year': '2016', 'overall_pick': '171', 'team': 'New York Rangers', 'player': 'Gabriel Fontaine', 'nationality': 'CA', 'position': 'C', 'age': '19', 'to_year': '', 'amateur_team': 'Rouyn-Noranda Huskies (QMJHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '1489', 'year': '2016', 'overall_pick': '174', 'team': 'New York Rangers', 'player': 'Tyler Wall', 'nationality': 'CA', 'position': 'G', 'age': '18', 'to_year': '', 'amateur_team': 'Leamington (GOJHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '1516', 'year': '2016', 'overall_pick': '201', 'team': 'New York Rangers', 'player': 'Ty Ronning', 'nationality': 'CA', 'position': 'RW', 'age': '18', 'to_year': '', 'amateur_team': 'Vancouver Giants (WHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '1567', 'year': '2015', 'overall_pick': '41', 'team': 'New York Rangers', 'player': 'Ryan Gropp', 'nationality': 'CA', 'position': 'LW', 'age': '18', 'to_year': '', 'amateur_team': 'Seattle Thunderbirds (WHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '1588', 'year': '2015', 'overall_pick': '62', 'team': 'New York Rangers', 'player': 'Robin Kovacs', 'nationality': 'SE', 'position': 'RW', 'age': '18', 'to_year': '', 'amateur_team': 'AIK (Sweden-2)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '1605', 'year': '2015', 'overall_pick': '79', 'team': 'New York Rangers', 'player': 'Sergey Zborovskiy', 'nationality': 'RU', 'position': 'D', 'age': '18', 'to_year': '', 'amateur_team': 'Regina Pats (WHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '1615', 'year': '2015', 'overall_pick': '89', 'team': 'New York Rangers', 'player': 'Aleksi Saarela', 'nationality': 'FI', 'position': 'C', 'age': '18', 'to_year': '2020', 'amateur_team': 'Assat (Finland)', 'games_played': '9', 'goals': '2', 'assists': '2', 'points': '4', 'plus_minus': '2', 'penalties_minutes': '0', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '0.5'}
# {'id': '1639', 'year': '2015', 'overall_pick': '113', 'team': 'New York Rangers', 'player': 'Brad Morrison', 'nationality': 'CA', 'position': 'C', 'age': '18', 'to_year': '', 'amateur_team': 'Prince George Cougars (WHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '1645', 'year': '2015', 'overall_pick': '119', 'team': 'New York Rangers', 'player': 'Daniel Bernhardt', 'nationality': 'SE', 'position': 'RW', 'age': '19', 'to_year': '', 'amateur_team': 'Djurgardens IF Jr. (Sweden Jr.)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '1710', 'year': '2015', 'overall_pick': '184', 'team': 'New York Rangers', 'player': 'Adam Huska', 'nationality': 'SK', 'position': 'G', 'age': '18', 'to_year': '2022', 'amateur_team': 'Green Bay Gamblers (USHL)', 'games_played': '1', 'goals': '0', 'assists': '0', 'points': '0', 'plus_minus': '', 'penalties_minutes': '0', 'goalie_games_played': '1', 'goalie_wins': '0', 'goalie_losses': '1', 'goalie_ties_overtime': '0', 'save_percentage': '0.821', 'goals_against_average': '7.04', 'point_shares': '-0.1'}
# {'id': '1796', 'year': '2014', 'overall_pick': '59', 'team': 'New York Rangers', 'player': 'Brandon Halverson', 'nationality': 'US', 'position': 'G', 'age': '18', 'to_year': '2018', 'amateur_team': 'Soo Greyhounds (OHL)', 'games_played': '1', 'goals': '0', 'assists': '0', 'points': '0', 'plus_minus': '0', 'penalties_minutes': '0', 'goalie_games_played': '1', 'goalie_wins': '0', 'goalie_losses': '0', 'goalie_ties_overtime': '0', 'save_percentage': '0.833', 'goals_against_average': '4.78', 'point_shares': '0'}
# {'id': '1822', 'year': '2014', 'overall_pick': '85', 'team': 'New York Rangers', 'player': 'Keegan Iverson', 'nationality': 'US', 'position': 'C/RW', 'age': '18', 'to_year': '', 'amateur_team': 'Portland Winterhawks (WHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '1841', 'year': '2014', 'overall_pick': '104', 'team': 'New York Rangers', 'player': 'Ryan Mantha', 'nationality': 'US', 'position': 'D', 'age': '18', 'to_year': '', 'amateur_team': 'Indiana Ice (USHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '1855', 'year': '2014', 'overall_pick': '118', 'team': 'New York Rangers', 'player': 'Igor Shesterkin', 'nationality': 'RU', 'position': 'G', 'age': '18', 'to_year': '2022', 'amateur_team': 'MHK Spartak Moskva (Russia Jr.)', 'games_played': '100', 'goals': '0', 'assists': '1', 'points': '1', 'plus_minus': '0', 'penalties_minutes': '2', 'goalie_games_played': '100', 'goalie_wins': '62', 'goalie_losses': '29', 'goalie_ties_overtime': '7', 'save_percentage': '0.928', 'goals_against_average': '2.31', 'point_shares': '23.5'}
# {'id': '1859', 'year': '2014', 'overall_pick': '122', 'team': 'New York Rangers', 'player': 'Richard Nejezchleb', 'nationality': 'CZ', 'position': 'LW', 'age': '20', 'to_year': '', 'amateur_team': 'Brandon Wheat Kings (WHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '1877', 'year': '2014', 'overall_pick': '140', 'team': 'New York Rangers', 'player': 'Daniel Walcott', 'nationality': 'CA', 'position': 'D', 'age': '20', 'to_year': '2021', 'amateur_team': 'Blainville-Boisbriand Armada (QMJHL)', 'games_played': '1', 'goals': '0', 'assists': '0', 'points': '0', 'plus_minus': '-1', 'penalties_minutes': '5', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '-0.1'}
# {'id': '1879', 'year': '2014', 'overall_pick': '142', 'team': 'New York Rangers', 'player': 'Tyler Nanne', 'nationality': 'US', 'position': 'D', 'age': '18', 'to_year': '', 'amateur_team': 'Edina HS (High-MN)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '2012', 'year': '2013', 'overall_pick': '65', 'team': 'New York Rangers', 'player': 'Adam Tambellini', 'nationality': 'CA', 'position': 'C', 'age': '18', 'to_year': '', 'amateur_team': 'Surrey (BCHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '2022', 'year': '2013', 'overall_pick': '75', 'team': 'New York Rangers', 'player': 'Pavel Buchnevich', 'nationality': 'RU', 'position': 'LW', 'age': '18', 'to_year': '2022', 'amateur_team': 'Almaz Cherepovets (Russia Jr.)', 'games_played': '374', 'goals': '109', 'assists': '162', 'points': '271', 'plus_minus': '36', 'penalties_minutes': '146', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '28.8'}
# {'id': '2027', 'year': '2013', 'overall_pick': '80', 'team': 'New York Rangers', 'player': 'Anthony Duclair', 'nationality': 'CA', 'position': 'LW', 'age': '18', 'to_year': '2022', 'amateur_team': 'Quebec Remparts (QMJHL)', 'games_played': '470', 'goals': '120', 'assists': '132', 'points': '252', 'plus_minus': '43', 'penalties_minutes': '163', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '28.5'}
# {'id': '2057', 'year': '2013', 'overall_pick': '110', 'team': 'New York Rangers', 'player': 'Ryan Graves', 'nationality': 'CA', 'position': 'D', 'age': '18', 'to_year': '2022', 'amateur_team': 'Prince Edward Island Rocket (QMJHL)', 'games_played': '224', 'goals': '20', 'assists': '54', 'points': '74', 'plus_minus': '50', 'penalties_minutes': '126', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '16.2'}
# {'id': '2117', 'year': '2013', 'overall_pick': '170', 'team': 'New York Rangers', 'player': 'Mackenzie Skapski', 'nationality': 'CA', 'position': 'G', 'age': '19', 'to_year': '2015', 'amateur_team': 'Kootenay Ice (WHL)', 'games_played': '2', 'goals': '0', 'assists': '0', 'points': '0', 'plus_minus': '0', 'penalties_minutes': '0', 'goalie_games_played': '2', 'goalie_wins': '2', 'goalie_losses': '0', 'goalie_ties_overtime': '0', 'save_percentage': '0.978', 'goals_against_average': '0.5', 'point_shares': '0.6'}
# {'id': '2186', 'year': '2012', 'overall_pick': '28', 'team': 'New York Rangers', 'player': 'Brady Skjei', 'nationality': 'US', 'position': 'D', 'age': '18', 'to_year': '2022', 'amateur_team': 'USA U-18 Development Team (USDP/USHL)', 'games_played': '448', 'goals': '37', 'assists': '125', 'points': '162', 'plus_minus': '-1', 'penalties_minutes': '252', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '27.9'}
# {'id': '2217', 'year': '2012', 'overall_pick': '59', 'team': 'New York Rangers', 'player': 'Cristoval Nieves', 'nationality': 'US', 'position': 'C', 'age': '18', 'to_year': '2020', 'amateur_team': 'Kent School (High-CT)', 'games_played': '76', 'goals': '5', 'assists': '14', 'points': '19', 'plus_minus': '3', 'penalties_minutes': '24', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '1.4'}
# {'id': '2277', 'year': '2012', 'overall_pick': '119', 'team': 'New York Rangers', 'player': 'Calle Andersson', 'nationality': 'SE', 'position': 'D', 'age': '18', 'to_year': '', 'amateur_team': 'Farjestad BK Jr. (Sweden Jr.)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '2300', 'year': '2012', 'overall_pick': '142', 'team': 'New York Rangers', 'player': 'Thomas Spelling', 'nationality': 'DK', 'position': 'RW', 'age': '19', 'to_year': '', 'amateur_team': 'Herning (Denmark)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '2384', 'year': '2011', 'overall_pick': '15', 'team': 'New York Rangers', 'player': 'J.T. Miller', 'nationality': 'US', 'position': 'C', 'age': '18', 'to_year': '2022', 'amateur_team': 'USA U-18 Development Team (USDP/USHL)', 'games_played': '637', 'goals': '169', 'assists': '285', 'points': '454', 'plus_minus': '42', 'penalties_minutes': '323', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '48'}
# {'id': '2441', 'year': '2011', 'overall_pick': '72', 'team': 'New York Rangers', 'player': 'Steven Fogarty', 'nationality': 'US', 'position': 'C', 'age': '18', 'to_year': '2022', 'amateur_team': 'Edina HS (High-MN)', 'games_played': '29', 'goals': '1', 'assists': '2', 'points': '3', 'plus_minus': '-2', 'penalties_minutes': '12', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '0'}
# {'id': '2475', 'year': '2011', 'overall_pick': '106', 'team': 'New York Rangers', 'player': 'Michael St. Croix', 'nationality': 'CA', 'position': 'C', 'age': '18', 'to_year': '', 'amateur_team': 'Edmonton Oil Kings (WHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '2503', 'year': '2011', 'overall_pick': '134', 'team': 'New York Rangers', 'player': 'Shane McColgan', 'nationality': 'US', 'position': 'RW', 'age': '18', 'to_year': '', 'amateur_team': 'Kelowna Rockets (WHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '2505', 'year': '2011', 'overall_pick': '136', 'team': 'New York Rangers', 'player': 'Samuel Noreau', 'nationality': 'CA', 'position': 'D', 'age': '18', 'to_year': '', 'amateur_team': 'Baie-Comeau Drakkar (QMJHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '2541', 'year': '2011', 'overall_pick': '172', 'team': 'New York Rangers', 'player': 'Peter Ceresnak', 'nationality': 'SK', 'position': 'D', 'age': '18', 'to_year': '', 'amateur_team': 'HK Dukla Trencin Jr. (Slovakia Jr.)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '2590', 'year': '2010', 'overall_pick': '10', 'team': 'New York Rangers', 'player': 'Dylan McIlrath', 'nationality': 'CA', 'position': 'D', 'age': '18', 'to_year': '2020', 'amateur_team': 'Moose Jaw Warriors (WHL)', 'games_played': '66', 'goals': '3', 'assists': '2', 'points': '5', 'plus_minus': '2', 'penalties_minutes': '121', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '1.9'}
# {'id': '2620', 'year': '2010', 'overall_pick': '40', 'team': 'New York Rangers', 'player': 'Christian Thomas', 'nationality': 'CA', 'position': 'RW', 'age': '18', 'to_year': '2016', 'amateur_team': 'Oshawa Generals (OHL)', 'games_played': '27', 'goals': '1', 'assists': '2', 'points': '3', 'plus_minus': '-2', 'penalties_minutes': '9', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '0'}
# {'id': '2680', 'year': '2010', 'overall_pick': '100', 'team': 'New York Rangers', 'player': 'Andrew Yogan', 'nationality': 'US', 'position': 'C/LW', 'age': '18', 'to_year': '', 'amateur_team': 'Erie Otters (OHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '2710', 'year': '2010', 'overall_pick': '130', 'team': 'New York Rangers', 'player': 'Jason Wilson', 'nationality': 'CA', 'position': 'LW', 'age': '20', 'to_year': '', 'amateur_team': 'Owen Sound Attack (OHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '2737', 'year': '2010', 'overall_pick': '157', 'team': 'New York Rangers', 'player': 'Jesper Fast', 'nationality': 'SE', 'position': 'RW', 'age': '18', 'to_year': '2022', 'amateur_team': 'HV71 Jr. (Sweden Jr.)', 'games_played': '550', 'goals': '75', 'assists': '125', 'points': '200', 'plus_minus': '32', 'penalties_minutes': '134', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '15.8'}
# {'id': '2770', 'year': '2010', 'overall_pick': '190', 'team': 'New York Rangers', 'player': 'Randy McNaught', 'nationality': 'CA', 'position': 'RW', 'age': '20', 'to_year': '', 'amateur_team': 'Saskatoon Blades (WHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '2809', 'year': '2009', 'overall_pick': '19', 'team': 'New York Rangers', 'player': 'Chris Kreider', 'nationality': 'US', 'position': 'C', 'age': '18', 'to_year': '2022', 'amateur_team': 'Phillips Andover Academy (High-MA)', 'games_played': '654', 'goals': '229', 'assists': '194', 'points': '423', 'plus_minus': '86', 'penalties_minutes': '499', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '53.5'}
# {'id': '2837', 'year': '2009', 'overall_pick': '47', 'team': 'New York Rangers', 'player': 'Ethan Werek', 'nationality': 'CA', 'position': 'C', 'age': '18', 'to_year': '', 'amateur_team': 'Kingston Frontenacs (OHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '2870', 'year': '2009', 'overall_pick': '80', 'team': 'New York Rangers', 'player': 'Ryan Bourque', 'nationality': 'US', 'position': 'C', 'age': '18', 'to_year': '2015', 'amateur_team': 'USA U-18 Development Team (USDP/NAHL)', 'games_played': '1', 'goals': '0', 'assists': '0', 'points': '0', 'plus_minus': '-1', 'penalties_minutes': '0', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '-0.1'}
# {'id': '2916', 'year': '2009', 'overall_pick': '127', 'team': 'New York Rangers', 'player': 'Roman Horak', 'nationality': 'CZ', 'position': 'C', 'age': '18', 'to_year': '2014', 'amateur_team': 'HC Mountfield (Czech)', 'games_played': '84', 'goals': '6', 'assists': '13', 'points': '19', 'plus_minus': '-3', 'penalties_minutes': '16', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '1.2'}
# {'id': '2929', 'year': '2009', 'overall_pick': '140', 'team': 'New York Rangers', 'player': 'Scott Stajcer', 'nationality': 'CA', 'position': 'G', 'age': '18', 'to_year': '', 'amateur_team': 'Owen Sound Attack (OHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '2959', 'year': '2009', 'overall_pick': '170', 'team': 'New York Rangers', 'player': 'Dan Maggio', 'nationality': 'CA', 'position': 'D', 'age': '18', 'to_year': '', 'amateur_team': 'Sudbury Wolves (OHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '2989', 'year': '2009', 'overall_pick': '200', 'team': 'New York Rangers', 'player': 'Mikhail Pashnin', 'nationality': 'RU', 'position': 'D', 'age': '20', 'to_year': '', 'amateur_team': 'Mechel Chelyabinsk (Russia-2)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# ...
# {'id': '11954', 'year': '1970', 'overall_pick': '25', 'team': 'New York Rangers', 'player': 'Mike Murphy', 'nationality': 'CA', 'position': 'RW', 'age': '20', 'to_year': '1983', 'amateur_team': 'Toronto Marlboros (OHA-Jr.)', 'games_played': '831', 'goals': '238', 'assists': '318', 'points': '556', 'plus_minus': '5', 'penalties_minutes': '514', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '41.1'}
# {'id': '11968', 'year': '1970', 'overall_pick': '39', 'team': 'New York Rangers', 'player': 'Wendell Bennett', 'nationality': 'CA', 'position': 'D', 'age': '', 'to_year': '', 'amateur_team': 'Weyburn (SJHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '11982', 'year': '1970', 'overall_pick': '53', 'team': 'New York Rangers', 'player': 'Andre St. Pierre', 'nationality': 'CA', 'position': 'D', 'age': '', 'to_year': '', 'amateur_team': 'Drummondville Rangers (QMJHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '11996', 'year': '1970', 'overall_pick': '67', 'team': 'New York Rangers', 'player': 'Gary Coalter', 'nationality': 'CA', 'position': 'RW', 'age': '20', 'to_year': '1975', 'amateur_team': 'Hamilton Red Wings (OHA-Jr.)', 'games_played': '34', 'goals': '2', 'assists': '4', 'points': '6', 'plus_minus': '-12', 'penalties_minutes': '2', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '-0.4'}
# {'id': '12010', 'year': '1970', 'overall_pick': '81', 'team': 'New York Rangers', 'player': 'Duane Wylie', 'nationality': 'US', 'position': 'C', 'age': '19', 'to_year': '1977', 'amateur_team': 'St. Catharines Black Hawks (OHA-Jr.)', 'games_played': '14', 'goals': '3', 'assists': '3', 'points': '6', 'plus_minus': '-5', 'penalties_minutes': '2', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '0.2'}
# {'id': '12023', 'year': '1970', 'overall_pick': '94', 'team': 'New York Rangers', 'player': 'Wayne Bell', 'nationality': 'CA', 'position': 'G', 'age': '', 'to_year': '', 'amateur_team': 'Estevan Bruins (WCHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '12035', 'year': '1970', 'overall_pick': '106', 'team': 'New York Rangers', 'player': "Pierre Brind'Amour", 'nationality': 'CA', 'position': 'LW', 'age': '', 'to_year': '', 'amateur_team': 'Montreal Jr. Canadiens (OHA-Jr.)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '12052', 'year': '1969', 'overall_pick': '8', 'team': 'New York Rangers', 'player': 'Andre Dupont', 'nationality': 'CA', 'position': 'D', 'age': '20', 'to_year': '1983', 'amateur_team': 'Montreal Jr. Canadiens (OHA-Jr.)', 'games_played': '810', 'goals': '59', 'assists': '185', 'points': '244', 'plus_minus': '302', 'penalties_minutes': '1986', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '62.9'}
# {'id': '12056', 'year': '1969', 'overall_pick': '12', 'team': 'New York Rangers', 'player': 'Pierre Jarry', 'nationality': 'CA', 'position': 'LW', 'age': '20', 'to_year': '1978', 'amateur_team': "Ottawa 67's (OHA-Jr.)", 'games_played': '344', 'goals': '88', 'assists': '117', 'points': '205', 'plus_minus': '-50', 'penalties_minutes': '142', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '13.8'}
# {'id': '12067', 'year': '1969', 'overall_pick': '23', 'team': 'New York Rangers', 'player': 'Bert Wilson', 'nationality': 'CA', 'position': 'LW', 'age': '19', 'to_year': '1981', 'amateur_team': 'London Knights (OHA-Jr.)', 'games_played': '478', 'goals': '37', 'assists': '44', 'points': '81', 'plus_minus': '-45', 'penalties_minutes': '646', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '-5.2'}
# {'id': '12079', 'year': '1969', 'overall_pick': '35', 'team': 'New York Rangers', 'player': 'Kevin Morrison', 'nationality': 'CA', 'position': 'D', 'age': '19', 'to_year': '1980', 'amateur_team': 'Saint-Jerome (QJHL-old)', 'games_played': '41', 'goals': '4', 'assists': '11', 'points': '15', 'plus_minus': '-5', 'penalties_minutes': '23', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '2.9'}
# {'id': '12091', 'year': '1969', 'overall_pick': '47', 'team': 'New York Rangers', 'player': 'Bruce Hellemond', 'nationality': 'CA', 'position': 'LW', 'age': '', 'to_year': '', 'amateur_team': 'Moose Jaw (SJHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '12103', 'year': '1969', 'overall_pick': '59', 'team': 'New York Rangers', 'player': 'Gord Smith', 'nationality': 'CA', 'position': 'D', 'age': '19', 'to_year': '1980', 'amateur_team': 'Cornwall (MMJHL)', 'games_played': '299', 'goals': '9', 'assists': '30', 'points': '39', 'plus_minus': '-141', 'penalties_minutes': '284', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '5.6'}
# {'id': '12147', 'year': '1968', 'overall_pick': '19', 'team': 'New York Rangers', 'player': 'Bruce Buchanan', 'nationality': 'CA', 'position': 'D', 'age': '', 'to_year': '', 'amateur_team': 'Weyburn Red Wings (CMJHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '12158', 'year': '1967', 'overall_pick': '6', 'team': 'New York Rangers', 'player': 'Robert Dickson', 'nationality': 'CA', 'position': 'LW', 'age': '', 'to_year': '', 'amateur_team': 'Chatham (WOJBHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '12167', 'year': '1967', 'overall_pick': '15', 'team': 'New York Rangers', 'player': 'Brian Tosh', 'nationality': 'CA', 'position': 'D', 'age': '', 'to_year': '', 'amateur_team': 'Smiths Falls (CJHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '12172', 'year': '1966', 'overall_pick': '2', 'team': 'New York Rangers', 'player': 'Brad Park', 'nationality': 'CA', 'position': 'D', 'age': '18', 'to_year': '1985', 'amateur_team': 'Toronto Marlboros (OHA-Jr.)', 'games_played': '1113', 'goals': '213', 'assists': '683', 'points': '896', 'plus_minus': '363', 'penalties_minutes': '1429', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '143.5'}
# {'id': '12178', 'year': '1966', 'overall_pick': '8', 'team': 'New York Rangers', 'player': 'Joey Johnston', 'nationality': 'CA', 'position': 'LW', 'age': '17', 'to_year': '1976', 'amateur_team': "Peterborough T.P.T's (OHA-Jr.)", 'games_played': '332', 'goals': '85', 'assists': '106', 'points': '191', 'plus_minus': '-123', 'penalties_minutes': '320', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '11.6'}
# {'id': '12184', 'year': '1966', 'overall_pick': '14', 'team': 'New York Rangers', 'player': 'Don Luce', 'nationality': 'CA', 'position': 'C', 'age': '17', 'to_year': '1982', 'amateur_team': 'Kitchener Rangers (OHA-Jr.)', 'games_played': '894', 'goals': '225', 'assists': '328', 'points': '553', 'plus_minus': '195', 'penalties_minutes': '364', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '44.1'}
# {'id': '12190', 'year': '1966', 'overall_pick': '20', 'team': 'New York Rangers', 'player': 'Jack Egers', 'nationality': 'CA', 'position': 'RW', 'age': '17', 'to_year': '1976', 'amateur_team': 'Kitchener Rangers (OHA-Jr.)', 'games_played': '284', 'goals': '64', 'assists': '69', 'points': '133', 'plus_minus': '0', 'penalties_minutes': '154', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '9.2'}
# {'id': '12195', 'year': '1965', 'overall_pick': '1', 'team': 'New York Rangers', 'player': 'Andre Veilleux', 'nationality': 'CA', 'position': 'RW', 'age': '', 'to_year': '', 'amateur_team': 'Montreal Rangers Jr. B ()', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '12200', 'year': '1965', 'overall_pick': '6', 'team': 'New York Rangers', 'player': 'George Surmay', 'nationality': 'CA', 'position': 'G', 'age': '', 'to_year': '', 'amateur_team': 'Winnipeg (MJHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '12204', 'year': '1965', 'overall_pick': '10', 'team': 'New York Rangers', 'player': 'Michel Parizeau', 'nationality': 'CA', 'position': 'C', 'age': '17', 'to_year': '1972', 'amateur_team': 'Montreal (MMJHL)', 'games_played': '58', 'goals': '3', 'assists': '14', 'points': '17', 'plus_minus': '-7', 'penalties_minutes': '18', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '0.1'}
# {'id': '12208', 'year': '1964', 'overall_pick': '3', 'team': 'New York Rangers', 'player': 'Robert Graham', 'nationality': 'CA', 'position': 'D', 'age': '', 'to_year': '', 'amateur_team': 'Toronto Marlboros (MetJAHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '12214', 'year': '1964', 'overall_pick': '9', 'team': 'New York Rangers', 'player': 'Tim Ecclestone', 'nationality': 'CA', 'position': 'LW', 'age': '16', 'to_year': '1978', 'amateur_team': 'Etobicoke (MetJBHL)', 'games_played': '692', 'goals': '126', 'assists': '233', 'points': '359', 'plus_minus': '20', 'penalties_minutes': '344', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '23.6'}
# {'id': '12220', 'year': '1964', 'overall_pick': '15', 'team': 'New York Rangers', 'player': 'Gordon Lowe', 'nationality': 'CA', 'position': 'D', 'age': '', 'to_year': '', 'amateur_team': 'Toronto Marlboros (MetJAHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '12226', 'year': '1964', 'overall_pick': '21', 'team': 'New York Rangers', 'player': 'Syl Apps', 'nationality': 'CA', 'position': 'C', 'age': '17', 'to_year': '1980', 'amateur_team': 'Kingston Midgets (RKMHA)', 'games_played': '727', 'goals': '183', 'assists': '423', 'points': '606', 'plus_minus': '36', 'penalties_minutes': '311', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': '46.3'}
# {'id': '12233', 'year': '1963', 'overall_pick': '4', 'team': 'New York Rangers', 'player': 'Al Osborne', 'nationality': 'CA', 'position': 'RW', 'age': '', 'to_year': '', 'amateur_team': 'Weston (MetJBHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '12239', 'year': '1963', 'overall_pick': '10', 'team': 'New York Rangers', 'player': 'Terry Jones', 'nationality': 'CA', 'position': 'C', 'age': '', 'to_year': '', 'amateur_team': 'Weston (MetJBHL)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '12244', 'year': '1963', 'overall_pick': '15', 'team': 'New York Rangers', 'player': 'Mike Cummins', 'nationality': 'CA', 'position': '', 'age': '', 'to_year': '', 'amateur_team': 'Georgetown Midgets (OHA-Jr.)', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}
# {'id': '12249', 'year': '1963', 'overall_pick': '20', 'team': 'New York Rangers', 'player': 'Campbell Alleson', 'nationality': 'CA', 'position': 'D', 'age': '', 'to_year': '', 'amateur_team': 'Portage la Prairie Jr. ()', 'games_played': '', 'goals': '', 'assists': '', 'points': '', 'plus_minus': '', 'penalties_minutes': '', 'goalie_games_played': '', 'goalie_wins': '', 'goalie_losses': '', 'goalie_ties_overtime': '', 'save_percentage': '', 'goals_against_average': '', 'point_shares': ''}

# %%
total_players_per_year = total_players_per_year(draft_data)
print("\nTotal players drafted per year:")
for year, count in total_players_per_year.items():
    print(f"Year: {year}, Total Players: {count}")
# Out:
# Total players drafted per year:
# Year: 2022, Total Players: 225
# Year: 2021, Total Players: 223
# Year: 2020, Total Players: 216
# Year: 2019, Total Players: 217
# Year: 2018, Total Players: 217
# Year: 2017, Total Players: 217
# Year: 2016, Total Players: 211
# Year: 2015, Total Players: 211
# Year: 2014, Total Players: 210
# Year: 2013, Total Players: 211
# Year: 2012, Total Players: 211
# Year: 2011, Total Players: 211
# Year: 2010, Total Players: 210
# Year: 2009, Total Players: 210
# Year: 2008, Total Players: 211
# Year: 2007, Total Players: 211
# Year: 2006, Total Players: 213
# Year: 2005, Total Players: 230
# Year: 2004, Total Players: 291
# Year: 2003, Total Players: 292
# Year: 2002, Total Players: 291
# Year: 2001, Total Players: 289
# Year: 2000, Total Players: 293
# Year: 1999, Total Players: 272
# Year: 1998, Total Players: 258
# Year: 1997, Total Players: 246
# Year: 1996, Total Players: 241
# Year: 1995, Total Players: 234
# Year: 1994, Total Players: 286
# Year: 1993, Total Players: 286
# Year: 1992, Total Players: 264
# Year: 1991, Total Players: 264
# Year: 1990, Total Players: 252
# Year: 1989, Total Players: 252
# Year: 1988, Total Players: 252
# Year: 1987, Total Players: 252
# Year: 1986, Total Players: 252
# Year: 1985, Total Players: 252
# Year: 1984, Total Players: 250
# Year: 1983, Total Players: 242
# Year: 1982, Total Players: 252
# Year: 1981, Total Players: 211
# Year: 1980, Total Players: 210
# Year: 1979, Total Players: 126
# Year: 1978, Total Players: 234
# Year: 1977, Total Players: 185
# Year: 1976, Total Players: 135
# Year: 1975, Total Players: 217
# Year: 1974, Total Players: 246
# Year: 1973, Total Players: 168
# Year: 1972, Total Players: 152
# Year: 1971, Total Players: 117
# Year: 1970, Total Players: 115
# Year: 1969, Total Players: 84
# Year: 1968, Total Players: 24
# Year: 1967, Total Players: 18
# Year: 1966, Total Players: 24
# Year: 1965, Total Players: 11
# Year: 1964, Total Players: 24
# Year: 1963, Total Players: 21

# %% [markdown]
# ## Exercise 4

# %%
import os
import pandas as pd
import zipfile
import tarfile

def read_book(filepath):
    with open(filepath, 'r', encoding='utf-8') as file:
        content = file.read()
    
    chapters = []
    current_chapter = []
    for line in content.split('\n'):
        if line.isupper() and line.strip():  # Assuming chapter titles are all caps and not empty
            if current_chapter:
                chapters.append('\n'.join(current_chapter))
                current_chapter = []
        current_chapter.append(line)
    if current_chapter:
        chapters.append('\n'.join(current_chapter))  # Add the last chapter

    return pd.DataFrame({'Chapter': chapters})

book = read_book('D:/Donwloads/The Adventures of Sherlock Holmes.txt')

# %%
def split_chapters_into_files(chapters_df, output_folder):
    """
    Generate separate text files for each chapter in the provided folder.
    
    Args:
    - chapters_df (pandas.DataFrame): DataFrame with separate chapters.
    - output_folder (str): Path to the folder where the chapter files will be saved.
    
    Returns:
    - None
    """
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    for idx, row in chapters_df.iterrows():
        chapter_num = f"{idx +1:02d}"
        chapter_filename = os.path.join(output_folder, f"chapter{chapter_num}.txt")
        with open(chapter_filename, 'w', encoding='utf-8') as file:
            file.write(row['Chapter'])

split_chapters_into_files(book, 'D:/Donwloads/Chapters')

# %%
def compress_files(input_folder, output_file, kind='zip'):
    """
    Compress the individual chapter text files into a zip or tar file.
    
    Args:
    - input_folder (str): Path to the folder containing the chapter files.
    - output_file (str): Path to the output compressed file.
    - kind (str, optional): Compression type. Default is 'zip'. Options are 'zip' or 'tar'.
    
    Returns:
    - None
    """
    if kind == 'zip':
        with zipfile.ZipFile(f"{output_file}.zip", 'w') as zipf:
            for foldername, subfolders, filenames in os.walk(input_folder):
                for filename in filenames:
                    file_path = os.path.join(foldername, filename)
                    zipf.write(file_path, os.path.relpath(file_path, input_folder))
    elif kind == 'tar':
        with tarfile.open(f"{output_file}.tar", 'w') as tar:
            for foldername, subfolders, filenames in os.walk(input_folder):
                for filename in filenames:
                    file_path = os.path.join(foldername, filename)
                    tar.add(file_path, arcname=os.path.relpath(file_path, input_folder))

compress_files('D:/Donwloads/Chapters', 'D:/Donwloads/The Adventures of Sherlock Holmes', kind='zip')
compress_files('D:/Donwloads/Chapters', 'D:/Donwloads/The Adventures of Sherlock Holmes', kind='tar')

# %%
def get_size(path):
    """
    Calculate and return the size of a file or folder in kilobytes.
    
    Args:
    - path (str): Path to the file or folder.
    
    Returns:
    - str: Size of the file or folder in kilobytes.
    """
    if os.path.isfile(path):
        size = os.path.getsize(path) / 1024
        return f"The size of the file '{path}' is {size:.2f} KB.", float(size)
    elif os.path.isdir(path):
        total_size = sum(os.path.getsize(os.path.join(root, file)) for root, _, files in os.walk(path) for file in files) / 1024
        return f"The size of the folder '{path}' is {total_size:.2f} KB.", float(total_size)
    else:
        return "Invalid path."

print(get_size("D:/Donwloads/Chapters"))
print(get_size("D:/Donwloads/The Adventures of Sherlock Holmes.zip"))
print(get_size("D:/Donwloads/The Adventures of Sherlock Holmes.tar"))
# Out:
# ("The size of the folder 'D:/Donwloads/Chapters' is 573.34 KB.", 573.3388671875)
# ("The size of the file 'D:/Donwloads/The Adventures of Sherlock Holmes.zip' is 574.56 KB.", 574.5556640625)
# ("The size of the file 'D:/Donwloads/The Adventures of Sherlock Holmes.tar' is 600.00 KB.", 600.0)

# %%
def test_get_size_folder():
    # Check the size of the Chapters folder
    folder, folder_size=get_size("D:/Donwloads/Chapters")
    assert folder_size>=555 and folder_size<=565,f"Unexpected folder size:{folder_size}KB"
    
test_get_size_folder()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[59], line 6
#       3     folder, folder_size=get_size("D:/Donwloads/Chapters")
#       4     assert folder_size>=555 and folder_size<=565,f"Unexpected folder size:{folder_size}KB"
# ----> 6 test_get_size_folder()
#
# Cell In[59], line 4, in test_get_size_folder()
#       1 def test_get_size_folder():
#       2     # Check the size of the Chapters folder
#       3     folder, folder_size=get_size("D:/Donwloads/Chapters")
# ----> 4     assert folder_size>=555 and folder_size<=565,f"Unexpected folder size:{folder_size}KB"
#
# AssertionError: Unexpected folder size:573.3388671875KB

# %% [markdown]
# #### we get this result since the file size is not between 555 and 565 KB

# %%
def test_get_size_zip():
    # Check the size of the zip file
    zip, zip_size=get_size("D:/Donwloads/The Adventures of Sherlock Holmes.zip")
    assert zip_size>=565 and zip_size<=575,f"Unexpected zip file size:{zip_size}KB"
    
test_get_size_zip()

# %%
def test_get_size_tar():
    # Check the size of the tar file
    tar, tar_size=get_size("D:/Donwloads/The Adventures of Sherlock Holmes.tar")
    assert tar_size>=585 and tar_size<=595,f"Unexpected tar file size:{tar_size}KB"
    
test_get_size_tar()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[61], line 6
#       3     tar, tar_size=get_size("D:/Donwloads/The Adventures of Sherlock Holmes.tar")
#       4     assert tar_size>=585 and tar_size<=595,f"Unexpected tar file size:{tar_size}KB"
# ----> 6 test_get_size_tar()
#
# Cell In[61], line 4, in test_get_size_tar()
#       1 def test_get_size_tar():
#       2     # Check the size of the tar file
#       3     tar, tar_size=get_size("D:/Donwloads/The Adventures of Sherlock Holmes.tar")
# ----> 4     assert tar_size>=585 and tar_size<=595,f"Unexpected tar file size:{tar_size}KB"
#
# AssertionError: Unexpected tar file size:600.0KB

# %% [markdown]
# #### we get this result since the file size is not between 585 and 595 KB
